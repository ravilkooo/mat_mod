# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from phase_port import phase_plane_plot, create_model

# %%
phase_plane_plot(create_model(4, 8),
                range_x=(-0.01, 0.01),
                num_grid_points=20, show=True,
                points=np.array([[0, 0]]))

# %%
phase_plane_plot(create_model(6, 3),
                range_x=(-0.04, 0.04),
                range_y=(-0.01, 0.01),
                num_grid_points=20, show=True,
                points=np.array([[0, 0]]))

# %%
phase_plane_plot(create_model(16, 8),
                range_x=(-0.04, 0.04),
                range_y=(-0.01, 0.01),
                num_grid_points=20, show=True,
                points=np.array([[0, 0]]))

# %%
phase_plane_plot(create_model(5, 2),
                range_x=(0.4, 1.),
                range_y=(0., 0.6),
                num_grid_points=20, show=True,
                points=np.array([[.6906474480, .2566844826]]))
